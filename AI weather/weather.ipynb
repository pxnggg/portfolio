# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv("seattle-weather.csv",usecols=[1,2,3,4,5])
data[0:32]
# Out:
#     precipitation  temp_max  temp_min  wind  weather
# 0             0.0      12.8       5.0   4.7  drizzle
# 1            10.9      10.6       2.8   4.5     rain
# 2             0.8      11.7       7.2   2.3     rain
# 3            20.3      12.2       5.6   4.7     rain
# 4             1.3       8.9       2.8   6.1     rain
# 5             2.5       4.4       2.2   2.2     rain
# 6             0.0       7.2       2.8   2.3     rain
# 7             0.0      10.0       2.8   2.0      sun
# 8             4.3       9.4       5.0   3.4     rain
# 9             1.0       6.1       0.6   3.4     rain
# 10            0.0       6.1      -1.1   5.1      sun
# 11            0.0       6.1      -1.7   1.9      sun
# 12            0.0       5.0      -2.8   1.3      sun
# 13            4.1       4.4       0.6   5.3     snow
# 14            5.3       1.1      -3.3   3.2     snow
# 15            2.5       1.7      -2.8   5.0     snow
# 16            8.1       3.3       0.0   5.6     snow
# 17           19.8       0.0      -2.8   5.0     snow
# 18           15.2      -1.1      -2.8   1.6     snow
# 19           13.5       7.2      -1.1   2.3     snow
# 20            3.0       8.3       3.3   8.2     rain
# 21            6.1       6.7       2.2   4.8     rain
# 22            0.0       8.3       1.1   3.6     rain
# 23            8.6      10.0       2.2   5.1     rain
# 24            8.1       8.9       4.4   5.4     rain
# 25            4.8       8.9       1.1   4.8     rain
# 26            0.0       6.7      -2.2   1.4  drizzle
# 27            0.0       6.7       0.6   2.2     rain
# 28           27.7       9.4       3.9   4.5     rain
# 29            3.6       8.3       6.1   5.1     rain
# 30            1.8       9.4       6.1   3.9     rain
# 31           13.5       8.9       3.3   2.7     rain

# %%
x = data.drop("weather",axis=1)
y = data['weather']
x.head()
# Out:
#    precipitation  temp_max  temp_min  wind
# 0            0.0      12.8       5.0   4.7
# 1           10.9      10.6       2.8   4.5
# 2            0.8      11.7       7.2   2.3
# 3           20.3      12.2       5.6   4.7
# 4            1.3       8.9       2.8   6.1

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3 , random_state=7)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_test[0:10]
# Out:
# 704      sun
# 957     rain
# 63      rain
# 1054    rain
# 1300    rain
# 997     rain
# 744      sun
# 791     rain
# 933     rain
# 619      sun
# Name: weather, dtype: object

# %%
y_predict = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy: 0.7744874715261959
